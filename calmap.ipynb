# %%
import numpy as np; np.random.seed(sum(map(ord, 'calmap')))
import pandas as pd
import calmap

all_days = pd.date_range('1/15/2014', periods=700, freq='D')
days = np.random.choice(all_days, 500)
events = pd.Series(np.random.randn(len(days)), index=days)

# %%
calmap.yearplot(events, cmap='RdYlGn', year=2015)

# %%
calmap.calendarplot(events, daylabels='MTWTFSS', cmap='YlGn',
                    fillcolor='grey', linewidth=0,
                    fig_kws=dict(figsize=(8, 4)))
# Out:
# (<Figure size 576x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001F32E19B4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F32DEBE550>],
#        dtype=object))
