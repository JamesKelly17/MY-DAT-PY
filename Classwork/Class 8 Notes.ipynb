# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('C:/Users/James.Kelly/DAT-06-24/class material/Unit 2/data/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.Sex.value_counts().plot(kind="bar", color=["orange","black"])

# %%
df.groupby('Sex')['Survived'].mean().plot(kind='barh', color=["purple","silver"])

# %%
df.groupby('Sex')[['Age', 'Fare']].mean().plot(kind='bar')
plt.title("test")
# Out:
# Text(0.5, 1.0, 'test')

# %%
df['Embarked'].value_counts().plot(kind='pie');

# %%
#Quant Data 
df['Age'].plot(kind='Hist', bins=20)

# %%
df.hist(column='Age', bins=10, by="Embarked", layout=(2,3), figsize=(12,4), sharey=True)
#plt.suptitle('Categorical Plotting')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df['Age'].plot(kind='kde') #shows probability data (kernel density estimate)

# %%
df.plot('Age', 'Fare', kind='scatter' ,color="red")
plt.xlabel('Age (years)')
plt.ylabel('Fare ($)')
plt.show()

# %%
df.plot('Age', 'Fare', kind='hexbin')
plt.title("My Boring Chart")
plt.show()

# %%
df.plot('Age', 'Fare', kind='scatter' ,color="red")

plt.show()

# %%
fig, ax = plt.subplots(1,2)
df[df.Sex == 'female'].plot('Age', 'Fare', kind='Scatter', ax=ax[0], color='red', label='Females')
df[df.Sex == 'male'].plot('Age', 'Fare', kind='Scatter', ax=ax[1], color='black', label='Males')

# %%
fig, ax = plt.subplots(2, 2)
ax
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E72BD9F710>,
# ...
#       dtype=object)

# %%
# this only grabs the axes in the first row!
ax[0]
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E72BD9F710>,
# ...
#       dtype=object)

# %%
# this grabs the the first axis in the first row
ax[0][0]

# %%
# this grabs the second axis in the second row
ax[1][1]

# %%
ax = df[df.Sex == 'female'].plot('Age', 'Fare', kind='Scatter', color='red', label='Females')
df[df.Sex == 'male'].plot('Age', 'Fare', kind='Scatter', ax=ax, label='Males')

# %%
#differnt types of plots in Seaborn
catplot
relplot
lmplot/regplot
distplot/jointplot
pairplot

# %%
# basic syntax for Seaborn - must specify x and y variables, as well as data source
sns.catplot(x='Pclass', y='Age', data=df)

# %%
# if you want to switch chart type, just use the 'kind' argument
sns.catplot(x='Pclass', y='Age', kind='swarm', hue='Sex', data=df)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.catplot(x='Pclass', y='Fare', kind='swarm', hue='Sex', data=df)

# %%
sns.catplot(x='Pclass', y='Fare', kind='swarm', row='Sex', data=df)

# %%
#types of charts

swarm
strip
box
boxen
violin
point
bar
count

# %%
sns.catplot(x='Pclass', y='Age', kind='bar', data=df)

# %%
sns.set_style("darkgrid")
sns.catplot(x='Pclass', y='Survived', kind='bar', hue='Sex', palette="bright", data=df);
plt.title("Survival Rate")
# Out:
# Text(0.5, 1.0, 'Survival Rate')

# %%
#quant data
#numeric column and numeric column

sns.lmplot(x='Pclass', y='Survived', data=df)

# %%
# a better looking histogram
df['Age'] = df['Age'].fillna(29)
sns.distplot(df.Age)

# %%
# and if you want to get fancier.....
sns.jointplot(x='Age', y='Fare', data=df[df.Sex == 'male'])

# %%
# this code would give you the previous plot
df['Age'] = df['Age'].fillna(29)
ax = sns.distplot(df[df.Sex == 'female']['Age'], label='Females')
sns.distplot(df[df.Sex == 'male']['Age'], label='Males', ax=ax)
plt.legend(loc='best')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-bf149cf69e97> in <module>
#       2 df['Age'] = df['Age'].fillna(29)
#       3 ax = sns.distplot(df[df.Sex == 'female']['Age'], label='Females')
# ----> 4 sns.distplot(df[df.Sex == 'male']['Age'], label='Males', ax=ax, aspect=10)
#       5 plt.legend(loc='best')
#
# TypeError: distplot() got an unexpected keyword argument 'aspect'

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, x_vars=['Pclass', 'Age', 'Fare', 'SibSp'], y_vars=['Age'])

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.033632 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.067814 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.334974  0.083081  0.018443
# Age             0.033632 -0.067814 -0.334974  1.000000 -0.232978 -0.176486
# SibSp          -0.057527 -0.035322  0.083081 -0.232978  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.176486  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.093706  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.093706
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(df.corr(), cmap="YlGnBu")

# %%
corr = np.corrcoef(df.corr())
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
