# %% [markdown]
# ### Autocorrelation, Autocovariance with the Airline Passengers Dataset

# %% [markdown]
# ##### Step 1:  Load in the Air Passangers Dataset

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
df = pd.read_csv('C:/Users/James.Kelly/DAT-06-24/class material/Unit 4/Class 18/data/AirPassengers.csv', index_col='Month', parse_dates=True)

# %% [markdown]
# ##### Step 2: Pull the head of the dataset, and plot it

# %%
# Your Code Here
df.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %%
df.plot();

# %% [markdown]
# ##### Step 3:  Calculate the Autocovariance at lag 3:

# %%
# Your Code Here
X_t = df[:-3]['Passengers'] - df['Passengers'].mean()
X_t_one = df[3:]['Passengers'] - df['Passengers'].mean()
X_covar = X_t.values * X_t_one.values
X_covar = X_covar.sum() * (1 / len(df))
X_covar/ df['Passengers'].var()
# Out:
# 0.8010792030277745

# %%
X_covar
# Out:
# 11529.065561302403

# %% [markdown]
# ##### Step 4:  Double Check Your Results Using the `acovf` function in Statsmodels

# %%
# Your Code Here
from statsmodels.tsa.stattools import acf, acovf

acf(df)
# Out:
# array([1.        , 0.94804734, 0.87557484, 0.80668116, 0.75262542,
#        0.71376997, 0.6817336 , 0.66290439, 0.65561048, 0.67094833,
#        0.70271992, 0.74324019, 0.76039504, 0.71266087, 0.64634228,
#        0.58592342, 0.53795519, 0.49974753, 0.46873401, 0.44987066,
#        0.4416288 , 0.45722376, 0.48248203, 0.51712699, 0.53218983,
#        0.49397569, 0.43772134, 0.3876029 , 0.34802503, 0.31498388,
#        0.28849682, 0.27080187, 0.26429011, 0.27679934, 0.2985215 ,
#        0.32558712, 0.3370236 , 0.30333486, 0.25397708, 0.21065534,
#        0.17217092])

# %% [markdown]
# ##### Step 5:  Plot the Autocorrelations using the `autocorrelation_plot` in Pandas (On The Entire Dataset)

# %%
# Your Code Here
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot
plt.style.use('fivethirtyeight')

autocorrelation_plot(df);
